# %% [markdown]
# Functions:
#   * Function it is a block of statements and function definnation starts with "def" keyword. it is a reusable block.
#   * The function defination executes whenever the function call occurs.

# %%
##Syntax:
#function defination
def fun_name(parameters:(optional)):
    #code
    # return expression/value(optional)
#fun1
res=fun_name(arguments)

# %%
def even_or_odd(x):
    if x%2 == 0:
        return'Even'
    else:
        return'Odd'
res = even_or_odd(10)
print(res)
res = even_or_odd(11)
print(res)
# Out:
# Even
# Odd

# %%
def even_or_odd(x):
    if x%2 == 0:
        print('Even')
    else:
        print('Odd')
n=int(input())
res = even_or_odd(n)
# Out:
#  76
# Even

# %%
def find_sum(numbers):
    total = 0
    for i in numbers:
        total = total + i
    return total
nums = [10, 20, 30, 40]
print("Sum is:", find_sum(nums))
# Out:
# Sum is: 100

# %%
def find_sum(numbers):
    total = 0
    for i in numbers:
        total = total + i
    return total
nums = [10, 20]
print("Sum is:", find_sum(nums))
# Out:
# Sum is: 30

# %%
def find_sum(numbers):
    total = 0
    for i in numbers:
        total = total + i
    return total
nums = [20, 30, 40]
print("Sum is:", find_sum(nums))
# Out:
# Sum is: 90
